# %%
# %pip install agent-framework python-dotenv chromadb pandas matplotlib scikit-learn rank_bm25
# Out:
# Requirement already satisfied: agent-framework in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (1.18.0)
# Requirement already satisfied: python-dotenv in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (1.2.3)
# Requirement already satisfied: chromadb in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (1.5.9)
# Requirement already satisfied: pandas in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (3.0.6)
# Requirement already satisfied: matplotlib in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (3.11.2)
# Requirement already satisfied: scikit-learn in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (1.9.1)
# Requirement already satisfied: rank_bm25 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (0.2.2)
# Requirement already satisfied: agent-framework-core==1.18.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.18.0)
# Requirement already satisfied: msgspec<0.22,>=0.20.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (0.21.1)
# Requirement already satisfied: typing-extensions<5,>=4.15.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (4.16.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (2.13.5)
# Requirement already satisfied: opentelemetry-api<2,>=1.39.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (1.44.0)
# Requirement already satisfied: mcp<2,>=1.24.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.30.0)
# Requirement already satisfied: agent-framework-a2a in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-ag-ui in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.3.0)
# Requirement already satisfied: agent-framework-anthropic in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-azure-ai-search in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-azure-contentunderstanding in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260813)
# Requirement already satisfied: agent-framework-azure-cosmos in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-azurefunctions in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260730)
# Requirement already satisfied: agent-framework-bedrock in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-chatkit in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-claude in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-copilotstudio in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-declarative in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.4)
# Requirement already satisfied: agent-framework-devui in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-durabletask in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260730)
# Requirement already satisfied: agent-framework-foundry in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.13.0)
# Requirement already satisfied: agent-framework-foundry-hosting in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-foundry-local in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260730)
# Requirement already satisfied: agent-framework-gemini in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-github-copilot in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (2.0.0)
# Requirement already satisfied: agent-framework-hyperlight in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-mem0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-mistral in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260903)
# Requirement already satisfied: agent-framework-monty in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260730)
# Requirement already satisfied: agent-framework-ollama in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260813)
# Requirement already satisfied: agent-framework-openai in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.14.3)
# Requirement already satisfied: agent-framework-orchestrations in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.1.1)
# Requirement already satisfied: agent-framework-purview in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-redis in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260910)
# Requirement already satisfied: agent-framework-tools in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b260730)
# Requirement already satisfied: anyio>=4.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (4.15.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2.15.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2.14.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.0.32)
# Requirement already satisfied: pywin32>=311 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (312)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (3.4.11)
# Requirement already satisfied: starlette>=0.48.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (1.6.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.4.4)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.53.0)
# Requirement already satisfied: certifi in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.18.0->agent-framework-core[all]==1.18.0->agent-framework) (2.46.5)
# Requirement already satisfied: build>=1.0.3 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.6.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (2.5.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (0.23.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (4.70.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (1.84.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (5.3.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (3.12.0)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pandas) (2026.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from scikit-learn) (3.7.0)
# Requirement already satisfied: pyproject_hooks in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.3.3)
# Requirement already satisfied: colorama in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.2)
# Requirement already satisfied: requests in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.2)
# Requirement already satisfied: requests-oauthlib in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.25.1)
# Requirement already satisfied: flatbuffers in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (50.0.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (2.1.1)
# Requirement already satisfied: pycparser in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.18.0->agent-framework) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.32.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (4.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.1.1)
# Requirement already satisfied: a2a-sdk<2,>=1.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (1.1.2)
# Requirement already satisfied: google-api-core>=1.26.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (2.37.0)
# Requirement already satisfied: json-rpc>=1.15.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (1.15.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.26.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (1.28.4)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (2.58.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.5.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<2,>=1.0.0->agent-framework-a2a->agent-framework-core[all]==1.18.0->agent-framework) (0.6.4)
# Requirement already satisfied: ag-ui-protocol<0.2,>=0.1.19 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.18.0->agent-framework) (0.1.22)
# Requirement already satisfied: fastapi<0.142.0,>=0.121.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.18.0->agent-framework) (0.141.1)
# Requirement already satisfied: anthropic<0.117.0,>=0.80.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-anthropic->agent-framework-core[all]==1.18.0->agent-framework) (0.116.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from anthropic<0.117.0,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.18.0->agent-framework) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from anthropic<0.117.0,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.18.0->agent-framework) (0.18.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from anthropic<0.117.0,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.18.0->agent-framework) (0.17.0)
# Requirement already satisfied: sniffio in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from anthropic<0.117.0,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.18.0->agent-framework) (1.3.1)
# Requirement already satisfied: azure-search-documents<13,>=12.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azure-ai-search->agent-framework-core[all]==1.18.0->agent-framework) (12.0.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-search-documents<13,>=12.0.0->agent-framework-azure-ai-search->agent-framework-core[all]==1.18.0->agent-framework) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-search-documents<13,>=12.0.0->agent-framework-azure-ai-search->agent-framework-core[all]==1.18.0->agent-framework) (1.41.0)
# Requirement already satisfied: azure-ai-contentunderstanding<2,>=1.2.0b2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azure-contentunderstanding->agent-framework-core[all]==1.18.0->agent-framework) (1.2.0b3)
# Requirement already satisfied: filetype<2,>=1.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azure-contentunderstanding->agent-framework-core[all]==1.18.0->agent-framework) (1.2.0)
# Requirement already satisfied: azure-ai-inference<1.0.0b10,>=1.0.0b9 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects<2.7.0,>=2.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (2.6.1)
# Requirement already satisfied: openai<4,>=2.25.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-openai->agent-framework-core[all]==1.18.0->agent-framework) (3.14.1)
# Requirement already satisfied: azure-identity>=1.15.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-ai-projects<2.7.0,>=2.2.0->agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (1.25.3)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-ai-projects<2.7.0,>=2.2.0->agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (12.30.2)
# Requirement already satisfied: httpx2<3,>=2.7.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from openai<4,>=2.25.0->agent-framework-openai->agent-framework-core[all]==1.18.0->agent-framework) (2.13.0)
# Requirement already satisfied: httpcore2==2.13.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4,>=2.25.0->agent-framework-openai->agent-framework-core[all]==1.18.0->agent-framework) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4,>=2.25.0->agent-framework-openai->agent-framework-core[all]==1.18.0->agent-framework) (0.10.4)
# Requirement already satisfied: msal>=1.35.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-identity>=1.15.0->azure-ai-projects<2.7.0,>=2.2.0->agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (1.38.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-identity>=1.15.0->azure-ai-projects<2.7.0,>=2.2.0->agent-framework-foundry->agent-framework-core[all]==1.18.0->agent-framework) (1.3.1)
# Requirement already satisfied: azure-cosmos<5,>=4.3.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azure-cosmos->agent-framework-core[all]==1.18.0->agent-framework) (4.17.1)
# Requirement already satisfied: azure-functions<2,>=1.24.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (1.25.0)
# Requirement already satisfied: azure-functions-durable<2,>=1.3.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (1.7.0)
# Requirement already satisfied: durabletask<2,>=1.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.18.0->agent-framework) (1.10.1)
# Requirement already satisfied: durabletask-azuremanaged<2,>=1.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.18.0->agent-framework) (1.10.1)
# Requirement already satisfied: werkzeug~=3.1.3 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (3.1.8)
# Requirement already satisfied: furl>=2.1.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (2.1.4)
# Requirement already satisfied: asyncio in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from durabletask<2,>=1.5.0->agent-framework-durabletask->agent-framework-core[all]==1.18.0->agent-framework) (4.0.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from werkzeug~=3.1.3->azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (3.0.3)
# Requirement already satisfied: orderedmultidict>=1.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from furl>=2.1.0->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.18.0->agent-framework) (1.0.2)
# Requirement already satisfied: boto3<2.0.0,>=1.35.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.18.0->agent-framework) (1.43.96)
# Requirement already satisfied: botocore<2.0.0,>=1.35.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.18.0->agent-framework) (1.43.96)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.18.0->agent-framework) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.18.0->agent-framework) (0.19.2)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.6.4 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-chatkit->agent-framework-core[all]==1.18.0->agent-framework) (1.6.5)
# Requirement already satisfied: openai-agents>=0.3.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from openai-chatkit<2.0.0,>=1.6.4->agent-framework-chatkit->agent-framework-core[all]==1.18.0->agent-framework) (0.22.2)
# Requirement already satisfied: jinja2<4,>=3.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from openai-chatkit<2.0.0,>=1.6.4->agent-framework-chatkit->agent-framework-core[all]==1.18.0->agent-framework) (3.1.6)
# Requirement already satisfied: griffelib<3,>=2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.6.4->agent-framework-chatkit->agent-framework-core[all]==1.18.0->agent-framework) (2.3.0)
# Requirement already satisfied: claude-agent-sdk<0.3,>=0.1.46 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-claude->agent-framework-core[all]==1.18.0->agent-framework) (0.2.154)
# Requirement already satisfied: microsoft-agents-copilotstudio-client<2,>=1.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-copilotstudio->agent-framework-core[all]==1.18.0->agent-framework) (1.5.0)
# Requirement already satisfied: microsoft-agents-hosting-core==1.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-agents-copilotstudio-client<2,>=1.2.0->agent-framework-copilotstudio->agent-framework-core[all]==1.18.0->agent-framework) (1.5.0)
# Requirement already satisfied: microsoft-agents-activity==1.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-agents-hosting-core==1.5.0->microsoft-agents-copilotstudio-client<2,>=1.2.0->agent-framework-copilotstudio->agent-framework-core[all]==1.18.0->agent-framework) (1.5.0)
# Requirement already satisfied: azure-ai-agentserver-core<3,>=2.1.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (2.1.0)
# Requirement already satisfied: azure-ai-agentserver-responses<3,>=2.2.0b1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (2.2.0b1)
# Requirement already satisfied: azure-ai-agentserver-invocations<2,>=1.1.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (1.1.0)
# Requirement already satisfied: hypercorn<1.0.0,>=0.17.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.18.0)
# Requirement already satisfied: microsoft-opentelemetry<2.0.0,>=1.3.5 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (1.3.9)
# Requirement already satisfied: h2>=4.3.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from hypercorn<1.0.0,>=0.17.0->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (4.4.1)
# Requirement already satisfied: priority in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from hypercorn<1.0.0,>=0.17.0->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (2.0.0)
# ...
# Requirement already satisfied: opentelemetry-instrumentation-fastapi<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-httpx<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-logging<0.66b0,>=0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-openai-agents-v2==0.1.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.1.0)
# Requirement already satisfied: opentelemetry-instrumentation-openai-v2==2.3b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (2.3b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure<1.0.0,>=0.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (1.17.3)
# Requirement already satisfied: opentelemetry-util-genai==0.3b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.3b0)
# Requirement already satisfied: msrest>=0.6.10 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b57->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b57->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (7.2.2)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-instrumentation-django<0.66b0,>=0.65b0->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-util-http==0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-instrumentation-django<0.66b0,>=0.65b0->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-instrumentation-fastapi<0.66b0,>=0.65b0->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: asgiref~=3.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-instrumentation-asgi==0.65b0->opentelemetry-instrumentation-fastapi<0.66b0,>=0.65b0->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (3.12.1)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.65b0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from opentelemetry-instrumentation-psycopg2<0.66b0,>=0.65b0->microsoft-opentelemetry<2.0.0,>=1.3.5->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (0.65b0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from h2>=4.3.0->hypercorn<1.0.0,>=0.17.0->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from h2>=4.3.0->hypercorn<1.0.0,>=0.17.0->azure-ai-agentserver-core<3,>=2.1.0->agent-framework-foundry-hosting->agent-framework-core[all]==1.18.0->agent-framework) (4.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: foundry-local-sdk<0.5.2,>=0.5.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-foundry-local->agent-framework-core[all]==1.18.0->agent-framework) (0.5.1)
# Requirement already satisfied: google-genai<3.0.0,>=1.69.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-gemini->agent-framework-core[all]==1.18.0->agent-framework) (2.24.0)
# Requirement already satisfied: github-copilot-sdk==1.0.11 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-github-copilot->agent-framework-core[all]==1.18.0->agent-framework) (1.0.11)
# Requirement already satisfied: hyperlight-sandbox<0.7,>=0.6.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-hyperlight->agent-framework-core[all]==1.18.0->agent-framework) (0.6.0)
# Requirement already satisfied: hyperlight-sandbox-backend-wasm<0.7,>=0.6.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-hyperlight->agent-framework-core[all]==1.18.0->agent-framework) (0.6.0)
# Requirement already satisfied: hyperlight-sandbox-python-guest<0.7,>=0.6.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-hyperlight->agent-framework-core[all]==1.18.0->agent-framework) (0.6.0)
# Requirement already satisfied: mem0ai<3,>=2.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (2.0.20)
# Requirement already satisfied: posthog>=7.14.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (7.54.0)
# Requirement already satisfied: pytz>=2024.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (2026.3.post1)
# Requirement already satisfied: qdrant-client>=1.12.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (1.19.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (2.0.54)
# Requirement already satisfied: backoff>=1.10.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from posthog>=7.14.0->mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (2.2.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from qdrant-client>=1.12.0->mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (3.2.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from sqlalchemy>=2.0.31->mem0ai<3,>=2.0.0->agent-framework-mem0->agent-framework-core[all]==1.18.0->agent-framework) (3.5.6)
# Requirement already satisfied: mistralai<3,>=2.9.2 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-mistral->agent-framework-core[all]==1.18.0->agent-framework) (2.10.1)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mistralai<3,>=2.9.2->agent-framework-mistral->agent-framework-core[all]==1.18.0->agent-framework) (0.4.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from mistralai<3,>=2.9.2->agent-framework-mistral->agent-framework-core[all]==1.18.0->agent-framework) (1.1.6)
# Requirement already satisfied: pydantic-monty<0.1,>=0.0.1 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-monty->agent-framework-core[all]==1.18.0->agent-framework) (0.0.23)
# Requirement already satisfied: pydantic-monty-client==0.0.23 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pydantic-monty<0.1,>=0.0.1->agent-framework-monty->agent-framework-core[all]==1.18.0->agent-framework) (0.0.23)
# Requirement already satisfied: pydantic-monty-runtime==0.0.23 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from pydantic-monty<0.1,>=0.0.1->agent-framework-monty->agent-framework-core[all]==1.18.0->agent-framework) (0.0.23)
# Requirement already satisfied: ollama<0.5.4,>=0.5.3 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-ollama->agent-framework-core[all]==1.18.0->agent-framework) (0.5.3)
# Requirement already satisfied: redis<7.2.1,>=6.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.18.0->agent-framework) (7.1.1)
# Requirement already satisfied: redisvl<0.16,>=0.11.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.18.0->agent-framework) (0.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.18.0->agent-framework) (1.8.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.18.0->agent-framework) (0.6.0)
# Requirement already satisfied: python-ulid>=3.0.0 in c:\Users\Ruwan\Desktop\pasan\HotelMate\Agentic Ai\hotelmate-booking-engine-copilot\backend\.venv\Lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.18.0->agent-framework) (4.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv



load_dotenv()
# Out:
# True

# %%
from agent_framework.openai import OpenAIChatClient, OpenAIEmbeddingClient

# %%
#define local Ollama (OpenAI-compatible) router settings
# Ollama exposes an OpenAI-compatible API at /v1 -- point OpenAIChatClient /
# OpenAIEmbeddingClient at it instead of a hosted Gemini/OpenAI backend.
# Make sure the models are pulled locally first, e.g.:
#   ollama pull llama3.1
#   ollama pull nomic-embed-text

OLLAMA_BASE_URL = os.getenv("OLLAMA_BASE_URL", "http://localhost:11434/v1")
CHAT_MODEL = os.getenv("OLLAMA_CHAT_MODEL", "gpt-oss:20b")
EMBEDDING_MODEL = os.getenv("OLLAMA_EMBEDDING_MODEL", "nomic-embed-text")

# Ollama ignores the key's value, but the OpenAI SDK requires a non-empty string
OLLAMA_API_KEY = os.getenv("OLLAMA_API_KEY", "ollama")

# %%
client = OpenAIChatClient(
    base_url=OLLAMA_BASE_URL,
    api_key=OLLAMA_API_KEY,
    model=CHAT_MODEL,
)

# %%
from pathlib import Path
import chromadb

# %%
#chromdb configuration

DATA_DIR = Path("documents")
CHROMA_DIR = Path("chroma_db")

COLLECTION_NAME = "hotelmate_knowledge"

chroma_client = chromadb.PersistentClient(
    path=str(CHROMA_DIR)
)

collection = chroma_client.get_or_create_collection(
    name=COLLECTION_NAME
)

# %%
#RAG PIPELINE STEP 1 : DATA Load and Chunking

# Load Markdown files
def load_markdown(file_path: Path) -> str:
    """
    Read a Markdown file as plain text.
    """

    return file_path.read_text(
        encoding="utf-8"
    )

# Chunk Markdown
def chunk_markdown(
    text: str,
    chunk_size: int = 1200,
    chunk_overlap: int = 200,
):
    """
    Split Markdown content into overlapping chunks.
    """

    # Normalize whitespace
    text = " ".join(text.split())

    chunks = []

    start = 0

    while start < len(text):

        end = start + chunk_size

        chunk = text[start:end].strip()

        if chunk:
            chunks.append(chunk)

        start += chunk_size - chunk_overlap

    return chunks

# %%
file_path = Path( Path(os.getenv("HOTEL_POLICY_DOC_PATH")) )

markdown = load_markdown(file_path)
print(markdown)
# Out:
# # Grand Horizon Hotel & Resort — Booking Policies
#
# **Document Type:** Knowledge Base Article
# **Category:** Reservations & Guest Policies
# **Last Updated:** 2026-09-01
# **Applicable Properties:** All Grand Horizon Hotel & Resort locations
#
# ---
#
# ## 1. Reservation Policy
#
# ### 1.1 How to Book
# Reservations can be made through:
# - The official website (grandhorizonhotels.com)
# - The Grand Horizon mobile app
# - Phone reservations (+1-800-555-0199)
# - Authorized third-party travel agents (Expedia, Booking.com, etc.)
#
# ### 1.2 Booking Confirmation
# - A confirmation email with a unique Booking Reference Number (format: GH-XXXXXXX) is sent within 15 minutes of booking.
# - Guests must present a valid government-issued photo ID and the credit card used for booking at check-in.
# - Group bookings (10+ rooms) require a signed contract and are handled by the Groups & Events desk.
#
# ### 1.3 Rate Types
# | Rate Type | Payment Timing | Flexibility |
# |---|---|---|
# | Flexible Rate | Charged at check-in | Free cancellation up to 24 hrs before arrival |
# | Advance Purchase | Charged in full at booking | Non-refundable, non-changeable |
# | Member Rate | Charged at check-in | Free cancellation up to 48 hrs before arrival (loyalty members only) |
# | Corporate Rate | Charged at check-in | Free cancellation up to 24 hrs before arrival (valid corporate ID required) |
#
# ---
#
# ## 2. Check-in / Check-out Policy
#
# - **Standard Check-in:** 3:00 PM local time
# - **Standard Check-out:** 11:00 AM local time
# - **Early Check-in:** Subject to availability; may incur a fee of 50% of one night's rate if before 10:00 AM
# - **Late Check-out:** Until 2:00 PM is complimentary for loyalty members (Gold tier and above); otherwise a fee of 50% of one night's rate applies
# - **Minimum Check-in Age:** 18 years, unless accompanied by a parent/guardian
# - Guests arriving after 11:00 PM must notify the hotel in advance via the "Late Arrival" option during booking to guarantee the room.
#
# ---
#
# ## 3. Cancellation & No-Show Policy
#
# ### 3.1 Cancellation Windows
# - **Flexible Rate:** Free cancellation up to 24 hours before the check-in date (local hotel time). Cancellations made after this window incur a charge equal to one night's stay plus applicable taxes.
# - **Advance Purchase Rate:** Non-refundable at time of booking. No cancellations or date changes permitted.
# - **Peak Season / Holiday Bookings (Dec 20–Jan 5, major local holidays):** Require 7 days' notice for free cancellation regardless of rate type.
#
# ### 3.2 No-Show Policy
# - If a guest does not arrive and does not cancel by the deadline, the full first night's charge (plus tax) is billed to the card on file.
# - The remainder of the reservation (subsequent nights) will be automatically released unless the guest contacts the hotel.
#
# ### 3.3 Refund Processing
# - Approved refunds are processed within 5–10 business days to the original payment method.
# - Refunds for bookings made through third-party platforms must be requested through that platform.
#
# ---
#
# ## 4. Modification Policy
#
# - Date, room type, or occupancy changes are permitted **only** for Flexible, Member, and Corporate rates, subject to availability.
# - Modifications must be made at least 24 hours before check-in.
# - Advance Purchase bookings cannot be modified; guests must cancel (forfeiting payment) and rebook.
# - Any modification that results in a rate change will be charged or refunded the difference.
#
# ---
#
# ## 5. Payment & Deposit Policy
#
# - Accepted payment methods: Visa, Mastercard, American Express, Discover, and UnionPay.
# - A valid credit card is required to guarantee all bookings; debit cards may be used but are subject to a pre-authorization hold.
# - Pre-authorization holds:
#   - Standard rooms: hold equal to one night's rate + estimated incidentals ($50/night)
#   - Suites: hold equal to one night's rate + estimated incidentals ($150/night)
# - Currency is charged in the local currency of the property unless otherwise stated.
# - Resort fees (where applicable) are mandatory and disclosed at the time of booking; they are **not** included in the room rate.
#
# ---
#
# ## 6. Occupancy & Extra Guest Policy
#
# - Standard room occupancy: 2 adults. Maximum occupancy varies by room type (see room descriptions).
# - Children under 12 stay free when using existing bedding.
# - Extra adult charge: $35/night (subject to property maximum occupancy limits).
# - Rollaway beds and cribs are available on request, subject to availability and a $20/night fee for rollaways (cribs are complimentary).
# - Pets: Only permitted at designated "Pet-Friendly" properties; a non-refundable pet fee of $75/stay applies, maximum 2 pets per room, weight limit 50 lbs per pet.
#
# ---
#
# ## 7. Loyalty Program & Discounts
#
# ### 7.1 Grand Horizon Rewards Tiers
# | Tier | Qualification | Key Benefits |
# |---|---|---|
# | Silver | Enrollment (free) | Points on stays, member-only rates |
# | Gold | 10 nights/year | Late check-out, room upgrades (subject to availability), welcome amenity |
# | Platinum | 25 nights/year | Guaranteed upgrade, lounge access, 48-hr free cancellation |
# | Diamond | 50 nights/year | Suite upgrades, dedicated concierge, guaranteed 4 PM late check-out |
#
# ### 7.2 Discount Codes
# - Promotional codes must be applied at the time of booking; they cannot be applied retroactively.
# - Discounts cannot be combined with other offers unless explicitly stated in the promotion terms.
#
# ---
#
# ## 8. Special Circumstances
#
# ### 8.1 Force Majeure
# In cases of natural disasters, government travel restrictions, or other events beyond guest control, cancellation fees may be waived at management's discretion upon review of supporting documentation.
#
# ### 8.2 Medical Emergencies
# Guests unable to travel due to a documented medical emergency may request a fee waiver by submitting medical documentation to guestrelations@grandhorizonhotels.com within 30 days of the original check-in date.
#
# ### 8.3 Overbooking / Walked Guests
# In the rare event a confirmed reservation cannot be honored due to overbooking, the hotel will:
# 1. Arrange comparable or superior accommodation at a nearby property at no additional cost.
# 2. Cover reasonable transportation to the alternate property.
# 3. Provide a compensation credit of $100 toward a future stay.
#
# ---
#
# ## 9. Frequently Asked Questions (Sample Q&A for RAG Retrieval)
#
# **Q: Can I cancel my reservation for free?**
# A: Yes, if you booked a Flexible, Member, or Corporate rate and cancel at least 24 hours before check-in (48 hours for Members, 7 days during peak season). Advance Purchase rates are non-refundable.
#
# **Q: What time is check-in and check-out?**
# A: Check-in is 3:00 PM and check-out is 11:00 AM. Early check-in and late check-out are available for a fee, subject to availability, and may be complimentary for Gold-tier loyalty members and above.
#
# **Q: Do you charge a fee for cancelling within 24 hours?**
# A: Yes, cancellations within 24 hours of check-in (or no-shows) are charged one night's rate plus applicable taxes.
#
# **Q: Can I bring my pet?**
# A: Only at designated pet-friendly properties, with a $75 non-refundable fee per stay, up to 2 pets under 50 lbs each.
#
# **Q: How do I get a refund after cancelling?**
# A: Approved refunds are returned to your original payment method within 5–10 business days. Bookings made via third-party sites must be refunded through that platform.
#
# **Q: Is there a minimum age to check in?**
# A: Yes, guests must be at least 18 years old unless accompanied by a parent or guardian.
#
# **Q: What happens if the hotel is overbooked and I have a confirmed reservation?**
# A: You will be relocated to a comparable or better nearby hotel at no extra cost, with transportation covered and a $100 credit toward a future stay.
#
# ---
#
# *This document is a synthetic sample created for testing agentic AI / RAG (Retrieval-Augmented Generation) systems. All property names, policies, and figures are fictional and intended for demonstration purposes only.*

# %%
chunks =chunk_markdown(markdown)
print(markdown)

print(f"Number of chunks: {len(chunks)}")
# Out:
# # Grand Horizon Hotel & Resort — Booking Policies
#
# **Document Type:** Knowledge Base Article
# **Category:** Reservations & Guest Policies
# **Last Updated:** 2026-09-01
# **Applicable Properties:** All Grand Horizon Hotel & Resort locations
#
# ---
#
# ## 1. Reservation Policy
#
# ### 1.1 How to Book
# Reservations can be made through:
# - The official website (grandhorizonhotels.com)
# - The Grand Horizon mobile app
# - Phone reservations (+1-800-555-0199)
# - Authorized third-party travel agents (Expedia, Booking.com, etc.)
#
# ### 1.2 Booking Confirmation
# - A confirmation email with a unique Booking Reference Number (format: GH-XXXXXXX) is sent within 15 minutes of booking.
# - Guests must present a valid government-issued photo ID and the credit card used for booking at check-in.
# - Group bookings (10+ rooms) require a signed contract and are handled by the Groups & Events desk.
#
# ### 1.3 Rate Types
# | Rate Type | Payment Timing | Flexibility |
# |---|---|---|
# | Flexible Rate | Charged at check-in | Free cancellation up to 24 hrs before arrival |
# | Advance Purchase | Charged in full at booking | Non-refundable, non-changeable |
# | Member Rate | Charged at check-in | Free cancellation up to 48 hrs before arrival (loyalty members only) |
# | Corporate Rate | Charged at check-in | Free cancellation up to 24 hrs before arrival (valid corporate ID required) |
#
# ---
#
# ## 2. Check-in / Check-out Policy
#
# - **Standard Check-in:** 3:00 PM local time
# - **Standard Check-out:** 11:00 AM local time
# - **Early Check-in:** Subject to availability; may incur a fee of 50% of one night's rate if before 10:00 AM
# - **Late Check-out:** Until 2:00 PM is complimentary for loyalty members (Gold tier and above); otherwise a fee of 50% of one night's rate applies
# - **Minimum Check-in Age:** 18 years, unless accompanied by a parent/guardian
# - Guests arriving after 11:00 PM must notify the hotel in advance via the "Late Arrival" option during booking to guarantee the room.
#
# ---
#
# ## 3. Cancellation & No-Show Policy
#
# ### 3.1 Cancellation Windows
# - **Flexible Rate:** Free cancellation up to 24 hours before the check-in date (local hotel time). Cancellations made after this window incur a charge equal to one night's stay plus applicable taxes.
# - **Advance Purchase Rate:** Non-refundable at time of booking. No cancellations or date changes permitted.
# - **Peak Season / Holiday Bookings (Dec 20–Jan 5, major local holidays):** Require 7 days' notice for free cancellation regardless of rate type.
#
# ### 3.2 No-Show Policy
# - If a guest does not arrive and does not cancel by the deadline, the full first night's charge (plus tax) is billed to the card on file.
# - The remainder of the reservation (subsequent nights) will be automatically released unless the guest contacts the hotel.
#
# ### 3.3 Refund Processing
# - Approved refunds are processed within 5–10 business days to the original payment method.
# - Refunds for bookings made through third-party platforms must be requested through that platform.
#
# ---
#
# ## 4. Modification Policy
#
# - Date, room type, or occupancy changes are permitted **only** for Flexible, Member, and Corporate rates, subject to availability.
# - Modifications must be made at least 24 hours before check-in.
# - Advance Purchase bookings cannot be modified; guests must cancel (forfeiting payment) and rebook.
# - Any modification that results in a rate change will be charged or refunded the difference.
#
# ---
#
# ## 5. Payment & Deposit Policy
#
# - Accepted payment methods: Visa, Mastercard, American Express, Discover, and UnionPay.
# - A valid credit card is required to guarantee all bookings; debit cards may be used but are subject to a pre-authorization hold.
# - Pre-authorization holds:
#   - Standard rooms: hold equal to one night's rate + estimated incidentals ($50/night)
#   - Suites: hold equal to one night's rate + estimated incidentals ($150/night)
# - Currency is charged in the local currency of the property unless otherwise stated.
# - Resort fees (where applicable) are mandatory and disclosed at the time of booking; they are **not** included in the room rate.
#
# ---
#
# ## 6. Occupancy & Extra Guest Policy
#
# - Standard room occupancy: 2 adults. Maximum occupancy varies by room type (see room descriptions).
# - Children under 12 stay free when using existing bedding.
# - Extra adult charge: $35/night (subject to property maximum occupancy limits).
# - Rollaway beds and cribs are available on request, subject to availability and a $20/night fee for rollaways (cribs are complimentary).
# - Pets: Only permitted at designated "Pet-Friendly" properties; a non-refundable pet fee of $75/stay applies, maximum 2 pets per room, weight limit 50 lbs per pet.
#
# ---
#
# ## 7. Loyalty Program & Discounts
#
# ### 7.1 Grand Horizon Rewards Tiers
# | Tier | Qualification | Key Benefits |
# |---|---|---|
# | Silver | Enrollment (free) | Points on stays, member-only rates |
# | Gold | 10 nights/year | Late check-out, room upgrades (subject to availability), welcome amenity |
# | Platinum | 25 nights/year | Guaranteed upgrade, lounge access, 48-hr free cancellation |
# | Diamond | 50 nights/year | Suite upgrades, dedicated concierge, guaranteed 4 PM late check-out |
#
# ### 7.2 Discount Codes
# - Promotional codes must be applied at the time of booking; they cannot be applied retroactively.
# - Discounts cannot be combined with other offers unless explicitly stated in the promotion terms.
#
# ---
#
# ## 8. Special Circumstances
#
# ### 8.1 Force Majeure
# In cases of natural disasters, government travel restrictions, or other events beyond guest control, cancellation fees may be waived at management's discretion upon review of supporting documentation.
#
# ### 8.2 Medical Emergencies
# Guests unable to travel due to a documented medical emergency may request a fee waiver by submitting medical documentation to guestrelations@grandhorizonhotels.com within 30 days of the original check-in date.
#
# ### 8.3 Overbooking / Walked Guests
# In the rare event a confirmed reservation cannot be honored due to overbooking, the hotel will:
# 1. Arrange comparable or superior accommodation at a nearby property at no additional cost.
# 2. Cover reasonable transportation to the alternate property.
# 3. Provide a compensation credit of $100 toward a future stay.
#
# ---
#
# ## 9. Frequently Asked Questions (Sample Q&A for RAG Retrieval)
#
# **Q: Can I cancel my reservation for free?**
# A: Yes, if you booked a Flexible, Member, or Corporate rate and cancel at least 24 hours before check-in (48 hours for Members, 7 days during peak season). Advance Purchase rates are non-refundable.
#
# **Q: What time is check-in and check-out?**
# A: Check-in is 3:00 PM and check-out is 11:00 AM. Early check-in and late check-out are available for a fee, subject to availability, and may be complimentary for Gold-tier loyalty members and above.
#
# **Q: Do you charge a fee for cancelling within 24 hours?**
# A: Yes, cancellations within 24 hours of check-in (or no-shows) are charged one night's rate plus applicable taxes.
#
# **Q: Can I bring my pet?**
# A: Only at designated pet-friendly properties, with a $75 non-refundable fee per stay, up to 2 pets under 50 lbs each.
#
# **Q: How do I get a refund after cancelling?**
# A: Approved refunds are returned to your original payment method within 5–10 business days. Bookings made via third-party sites must be refunded through that platform.
#
# **Q: Is there a minimum age to check in?**
# A: Yes, guests must be at least 18 years old unless accompanied by a parent or guardian.
#
# **Q: What happens if the hotel is overbooked and I have a confirmed reservation?**
# A: You will be relocated to a comparable or better nearby hotel at no extra cost, with transportation covered and a $100 credit toward a future stay.
#
# ---
#
# *This document is a synthetic sample created for testing agentic AI / RAG (Retrieval-Augmented Generation) systems. All property names, policies, and figures are fictional and intended for demonstration purposes only.*
#
# Number of chunks: 8

# %%
# RAG PIPELINE STEP 2: Generate vector embeddings and store them in the vector database
#
# This step takes the chunks produced in Step 1, converts each chunk into a
# vector embedding using Gemini's embedding model, and upserts the resulting
# (id, embedding, document, metadata) records into the Chroma collection.

# %%
# No custom embedding client class needed here anymore.
# OpenAIEmbeddingClient (imported above) already speaks the OpenAI-compatible
# embeddings API, so it works directly against Ollama's /v1/embeddings route.

# %%
# Initialize the embedding client (OpenAI-compatible, pointed at local Ollama)
embedding_client = OpenAIEmbeddingClient(
    base_url=OLLAMA_BASE_URL,
    api_key=OLLAMA_API_KEY,
    model=EMBEDDING_MODEL,
)

# %%
# Embed every chunk and upsert it into the Chroma collection
async def ingest_documents(
    chunks: list[str],
    collection=collection,
    embedding_client: OpenAIEmbeddingClient = embedding_client,
    batch_size: int = 32,
):
    """
    Generate vector embeddings for a list of text chunks and store each
    chunk (with its embedding and metadata) in the Chroma collection.
    Embeddings are requested in batches for efficiency.
    """

    total = len(chunks)

    for batch_start in range(0, total, batch_size):
        batch_end = min(batch_start + batch_size, total)
        batch_chunks = chunks[batch_start:batch_end]

        # Request embeddings for the whole batch in a single call
        generated = await embedding_client.get_embeddings(batch_chunks)
        # GeneratedEmbeddings IS the collection of Embedding objects (it behaves
        # like a list), so iterate over it directly rather than a sub-attribute.
        batch_vectors = [e.vector for e in generated]

        ids = [f"chunk-{i}" for i in range(batch_start, batch_end)]
        metadatas = [
            {"chunk_index": i, "file_type": "markdown"}
            for i in range(batch_start, batch_end)
        ]

        collection.upsert(
            ids=ids,
            embeddings=batch_vectors,
            documents=batch_chunks,
            metadatas=metadatas,
        )

        print(f"Embedded and stored chunks {batch_start + 1}-{batch_end}/{total}")

    print("\nEmbedding and ChromaDB storage completed.")

# %%
await ingest_documents(chunks)
# Out:
# Embedded and stored chunks 1-8/8
#
# Embedding and ChromaDB storage completed.

# %%
# Re-fetch the hotelmate_knowledge collection (already created by `chroma_client`
# above) -- reuse the existing client instead of creating a new one, so we don't
# overwrite the `client` variable that holds the OpenAIChatClient (local Ollama) used for the agent.
collection = chroma_client.get_collection(COLLECTION_NAME)

data = collection.get(
    include=["documents", "embeddings", "metadatas"]
)

print(f"Stored chunks: {len(data['ids'])}")
# Out:
# Stored chunks: 8

# %%
#visulaize above data using table
import pandas as pd

data = collection.get(
    include=[
        "documents",
        "metadatas",
        "embeddings"
    ]
)

df = pd.DataFrame({
    "id": data["ids"],
    "document": data["documents"],
    "metadata": data["metadatas"],
    "embedding_dimensions": [
        len(e) for e in data["embeddings"]
    ]
})

df
# Out:
#         id                                           document  \
# 0  chunk-0  # Grand Horizon Hotel & Resort — Booking Polic...
# 1  chunk-1  to 24 hrs before arrival | | Advance Purchase ...
# 2  chunk-2  ws - **Flexible Rate:** Free cancellation up t...
# 3  chunk-3  ype, or occupancy changes are permitted **only...
# 4  chunk-4  t** included in the room rate. --- ## 6. Occup...
# 5  chunk-5  | Diamond | 50 nights/year | Suite upgrades, d...
# 6  chunk-6  by property at no additional cost. 2. Cover re...
# 7  chunk-7  tay, up to 2 pets under 50 lbs each. **Q: How ...
#
#                                       metadata  embedding_dimensions
# 0  {'file_type': 'markdown', 'chunk_index': 0}                   768
# 1  {'file_type': 'markdown', 'chunk_index': 1}                   768
# 2  {'file_type': 'markdown', 'chunk_index': 2}                   768
# 3  {'file_type': 'markdown', 'chunk_index': 3}                   768
# 4  {'file_type': 'markdown', 'chunk_index': 4}                   768
# 5  {'file_type': 'markdown', 'chunk_index': 5}                   768
# 6  {'chunk_index': 6, 'file_type': 'markdown'}                   768
# 7  {'file_type': 'markdown', 'chunk_index': 7}                   768

# %%
#vector database collection called hotelmate_knowledge visualize using Principal component analysis 
# statistical method

import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

embeddings = np.array(data["embeddings"])

pca = PCA(n_components=2)

vectors_2d = pca.fit_transform(embeddings)

plt.figure(figsize=(10, 7))

plt.scatter(
    vectors_2d[:, 0],
    vectors_2d[:, 1]
)

plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.title("ChromaDB Embeddings Visualization")

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# RAG PIPELINE STEP 4: Query the vector database -- semantic, keyword, hybrid, metadata search
#
# 1. semantic_search  -> pure vector similarity (embeds the query, nearest
#    neighbors in Chroma). Strong on meaning/paraphrase, weak on exact terms.
# 2. keyword_search    -> BM25 (a standard unsupervised lexical ranking model,
#    same family as TF-IDF). Strong on exact terms, blind to meaning.
# 3. hybrid_search      -> Reciprocal Rank Fusion (RRF) of the two rankings.
#    Combines ranked lists without needing to normalize distance scores
#    against BM25 scores onto the same scale.
# 4. metadata_filtered_search -> semantic search restricted to a metadata
#    subset (e.g. only markdown docs, only a specific property) -- scopes
#    the candidate pool before ranking rather than being a ranking method
#    on its own.

# %%
import re
from rank_bm25 import BM25Okapi

def tokenize(text: str) -> list[str]:
    return re.findall(r"\w+", text.lower())

# Build the BM25 index once over all stored chunks (reuses `data` from above)
bm25_doc_ids = data["ids"]
bm25_documents = data["documents"]
bm25_corpus = [tokenize(doc) for doc in bm25_documents]
bm25 = BM25Okapi(bm25_corpus)

# %%
async def semantic_search(query: str, top_k: int = 3):
    """Pure vector similarity search against the Chroma collection."""

    generated = await embedding_client.get_embeddings([query])
    query_vector = [e.vector for e in generated][0]

    results = collection.query(
        query_embeddings=[query_vector],
        n_results=top_k,
    )

    return list(zip(
        results["ids"][0],
        results["documents"][0],
        results["distances"][0],
    ))

# %%
def keyword_search(query: str, top_k: int = 3):
    """Lexical search using BM25 over the stored chunk text."""

    scores = bm25.get_scores(tokenize(query))

    ranked = sorted(
        zip(bm25_doc_ids, bm25_documents, scores),
        key=lambda item: item[2],
        reverse=True,
    )

    return ranked[:top_k]

# %%
async def hybrid_search(query: str, top_k: int = 3, k_rrf: int = 60):
    """
    Combine semantic and keyword rankings via Reciprocal Rank Fusion (RRF).

    Each result's fused score is the sum of 1 / (k_rrf + rank) across the
    lists it appears in, so a chunk that ranks well in *both* semantic and
    keyword search rises to the top -- without needing to normalize a cosine
    distance against a BM25 score.
    """

    semantic_results = await semantic_search(query, top_k=len(bm25_doc_ids))
    keyword_results = keyword_search(query, top_k=len(bm25_doc_ids))

    rrf_scores: dict[str, float] = {}

    for rank, (doc_id, _doc, _distance) in enumerate(semantic_results):
        rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + 1 / (k_rrf + rank + 1)

    for rank, (doc_id, _doc, _score) in enumerate(keyword_results):
        rrf_scores[doc_id] = rrf_scores.get(doc_id, 0.0) + 1 / (k_rrf + rank + 1)

    id_to_doc = dict(zip(bm25_doc_ids, bm25_documents))
    ranked_ids = sorted(rrf_scores.items(), key=lambda item: item[1], reverse=True)

    return [
        (doc_id, id_to_doc[doc_id], score)
        for doc_id, score in ranked_ids[:top_k]
    ]

# %%
async def metadata_filtered_search(query: str, top_k: int = 3, where: dict | None = None):
    """
    Semantic search restricted to chunks matching a metadata filter.
    e.g. where={"file_type": "markdown"} -- scopes the candidate pool
    *before* ranking, useful once you have multiple documents/properties
    stored in the same collection.
    """

    generated = await embedding_client.get_embeddings([query])
    query_vector = [e.vector for e in generated][0]

    results = collection.query(
        query_embeddings=[query_vector],
        n_results=top_k,
        where=where,
    )

    return list(zip(
        results["ids"][0],
        results["documents"][0],
        results["distances"][0],
    ))

# %%
semantic_query = "Can I bring my two dogs when I stay?"  

print("=== Semantic search ===")
print(f"Query: {semantic_query!r}")
for doc_id, doc, distance in await semantic_search(semantic_query):
    print(f"[{doc_id}] distance={distance:.4f}  {doc[:100]}...")

# %%
keyword_query = "What's the resort fee?" 

print("\n=== Keyword search (BM25) ===")
print(f"Query: {keyword_query!r}")
for doc_id, doc, score in keyword_search(keyword_query):
    print(f"[{doc_id}] bm25={score:.4f}  {doc[:100]}...")

# %%
hybrid_query = "What's the deal if I cancel my Advance Purchase booking last minute?"   # mixes a named rate + a vague ask

print("\n=== Hybrid search (RRF) ===")
print(f"Query: {hybrid_query!r}")
for doc_id, doc, score in await hybrid_search(hybrid_query):
    print(f"[{doc_id}] rrf={score:.4f}  {doc[:100]}...")

# %%
metadata_query = "What is the cancellation policy?"   

print("\n=== Metadata-filtered semantic search (file_type=markdown) ===")
print(f"Query: {metadata_query!r}")
for doc_id, doc, distance in await metadata_filtered_search(metadata_query, where={"file_type": "markdown"}):
    print(f"[{doc_id}] distance={distance:.4f}  {doc[:100]}...")

# %%
# RAG PIPELINE STEP 5: Agentic RAG -- give the agent a retrieval tool
#
# This is what makes it *agentic* RAG rather than plain RAG: instead of us
# always fetching chunks and stuffing them into the prompt, we hand the LLM
# a callable tool. The agent itself decides -- per user message -- whether
# the question needs a policy lookup at all, and if so, what to search for.

from typing import Annotated

from agent_framework import Agent

# %%
async def search_hotel_policies(
    query: Annotated[str, "The guest's question, used to search the hotel policy knowledge base."],
) -> str:
    """
    Search the Grand Horizon Hotel & Resort booking-policy knowledge base
    and return the most relevant policy excerpts for the given question.
    Call this whenever the guest asks about reservations, cancellations,
    check-in/out times, payments, occupancy, pets, loyalty tiers, or any
    other hotel booking policy. Do not guess at policy details without
    calling this first.
    """

    results = await hybrid_search(query, top_k=3)

    if not results:
        return "No relevant policy information was found."

    return "\n\n".join(
        f"[{doc_id}] {doc}" for doc_id, doc, _score in results
    )

# %%
agent = Agent(
    client=client,  # the OpenAIChatClient (local Ollama) from earlier -- no longer shadowed
    name="HotelPolicyAgent",
    instructions=(
        "You are the Grand Horizon Hotel & Resort booking assistant. "
        "Use the search_hotel_policies tool to look up the hotel's actual "
        "policies before answering any question about reservations, "
        "cancellations, check-in/out, payments, occupancy, pets, or loyalty "
        "programs. Answer only from what the tool returns -- if the tool "
        "doesn't cover something, say you don't have that information "
        "rather than guessing. Keep answers brief and guest-friendly."
    ),
    tools=[search_hotel_policies],
)

# %%
async def run_agent(prompt):
    print("You: " + prompt)
    response = await agent.run(prompt)
    print(response)

# %%
await run_agent("What's the cancellation policy for an Advance Purchase booking?")

# %%
await run_agent("Can I bring my two dogs when I stay?")
